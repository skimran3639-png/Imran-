# %% [markdown]
# <a href="https://colab.research.google.com/github/skimran3639-png/Imran-/blob/main/Copy_of_similarity_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline
#load text generation model (genAI)
gegnerator =pipeline(
    "text-generation",
    model="gpt2"
)
#input prompt
prompt= " artificial intelligence in financial will"
#generation text
result =generator (prompt, max_length_=50, num_return_sequence=1)
print("AI GENERATED TEXT:")
print("result[0][generated_text]")
